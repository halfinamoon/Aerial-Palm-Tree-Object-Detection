# %%
# Importing Necessary Packages
from ultralytics import YOLO
from roboflow import Roboflow
from IPython.display import Image as IPyImage
from ultralytics.utils.benchmarks import benchmark
import cv2
import numpy as np
import time

# %%
#TRAINING MODEL

#load dataset and model selection
dataset_path = "/workspace/palmtree/Palm-Tree-Detection-1/data.yaml"
model = YOLO("yolo11n.pt")  # load a pretrained model (trained on general multi class COCO dataset)

#Start the training process
results = model.train(data=dataset_path, epochs=150, imgsz=640, device=0, plots=True)
# Out:
# Ultralytics 8.3.91 🚀 Python-3.11.11 torch-2.6.0+cu126 CUDA:0 (NVIDIA GeForce RTX 4080 SUPER, 16077MiB)
# ...

# %%
# Overall Training Metrics Result 
IPyImage(filename='/workspace/palmtree/runs/detect/train6/results.png', width=600)

# %%
# F1 Curve Metrics Result 
IPyImage(filename='/workspace/palmtree/runs/detect/train6/F1_curve.png', width=600)

# %%
# F1 Curve Metrics Result
IPyImage(filename='/workspace/palmtree/runs/detect/train6/confusion_matrix.png', width=600)

# %%
# Precision-Recall Curve Metrics Result
IPyImage(filename='/workspace/palmtree/runs/detect/train6/PR_curve.png', width=600)

# %%
# Benchmark on GPU
benchmark(model="/workspace/palmtree/runs/detect/train6/weights/best.pt", data=dataset_path, imgsz=640, half=False, device=0)
# Out:
# Setup complete ✅ (12 CPUs, 31.3 GB RAM, 15.8/110.0 GB disk)
#
# Benchmarks complete for /workspace/palmtree/runs/detect/train6/weights/best.pt on /workspace/palmtree/Palm-Tree-Detection-1/data.yaml at imgsz=640 (10.62s)
# Benchmarks legend:  - ✅ Success  - ❎ Export passed but validation failed  - ❌️ Export failed
#                    Format Status❔  Size (MB) metrics/mAP50-95(B) Inference time (ms/im)     FPS
# 0                 PyTorch       ✅        5.2              0.6867                   6.81   146.9
# 1             TorchScript       ✅       10.4              0.6346                   3.42  292.13
# 2                    ONNX       ❌        0.0                   -                      -       -
# 3                OpenVINO       ❌        0.0                   -                      -       -
# 4                TensorRT       ❌        0.0                   -                      -       -
# ...

# %%
# Benchmark on CPU
benchmark(model="/workspace/palmtree/runs/detect/train6/weights/best.pt", data=dataset_path, imgsz=640, half=False, device="cpu")
# Out:
# Setup complete ✅ (12 CPUs, 31.3 GB RAM, 15.9/110.0 GB disk)
#
# Benchmarks complete for /workspace/palmtree/runs/detect/train6/weights/best.pt on /workspace/palmtree/Palm-Tree-Detection-1/data.yaml at imgsz=640 (20.84s)
# Benchmarks legend:  - ✅ Success  - ❎ Export passed but validation failed  - ❌️ Export failed
#                    Format Status❔  Size (MB) metrics/mAP50-95(B) Inference time (ms/im)    FPS
# 0                 PyTorch       ✅        5.2              0.6867                   47.9  20.88
# 1             TorchScript       ✅       10.4              0.6346                  49.91  20.04
# 2                    ONNX       ❌        0.0                   -                      -      -
# 3                OpenVINO       ❌        0.0                   -                      -      -
# 4                TensorRT       ❌        0.0                   -                      -      -
# 5                  CoreML       ❌        0.0                   -                      -      -
# ...

# %%
# Enhanced Palm Tree Detection with Blue Bounding Boxes and Processing Time


def detect_trees_with_tiling(image_path, model, tile_size=640, overlap=0.2, conf_threshold=0.3, iou_threshold=0.7):
    # Start timing
    start_time = time.time()
    
    # Load image
    print(f"Loading image: {image_path}")
    image = cv2.imread(image_path)
    if image is None:
        print(f"Error: Could not load image at {image_path}")
        return None, 0
        
    h, w = image.shape[:2]
    print(f"Image dimensions: {w}x{h}")
    
    # Create result image for visualization
    result_image = image.copy()
    
    # Calculate step size with overlap
    step = int(tile_size * (1 - overlap))
    print(f"Processing with tile size: {tile_size}px, overlap: {overlap*100}%, step: {step}px")
    
    all_detections = []
    tree_count = 0
    tiles_processed = 0
    
    # Process each tile
    for y in range(0, h-tile_size+1, step):
        for x in range(0, w-tile_size+1, step):
            # Extract tile
            tile = image[y:y+tile_size, x:x+tile_size]
            tiles_processed += 1
            
            # # For large images, show progress
            # if tiles_processed % 10 == 0:
            #     print(f"Processing tile {tiles_processed}...")
            
            # Run detection on tile
            results = model(tile, conf=conf_threshold, iou=iou_threshold)
            
            # Process detections in this tile
            if len(results[0].boxes) > 0:
                for box in results[0].boxes.xyxy:
                    # Adjust coordinates to original image
                    x1, y1, x2, y2 = map(int, box)
                    global_x1, global_y1 = x1 + x, y1 + y
                    global_x2, global_y2 = x2 + x, y2 + y
                    
                    # Check if this detection overlaps with previous ones
                    new_detection = True
                    for prev_box in all_detections:
                        if calculate_iou(prev_box, (global_x1, global_y1, global_x2, global_y2)) > 0.5:
                            new_detection = False
                            break
                    
                    if new_detection:
                        all_detections.append((global_x1, global_y1, global_x2, global_y2))
                        tree_count += 1
                        
                        # Draw BLUE box and number
                        blue_color = (255, 0, 0)  # BGR: Blue
                        cv2.rectangle(result_image, (global_x1, global_y1), (global_x2, global_y2), blue_color, 2)
                        
                        # Add white background to text for better visibility
                        text = str(tree_count)
                        text_size = cv2.getTextSize(text, cv2.FONT_HERSHEY_SIMPLEX, 0.5, 2)[0]
                        cv2.rectangle(result_image, 
                                     (global_x1, global_y1-text_size[1]-10), 
                                     (global_x1+text_size[0], global_y1), 
                                     (255, 255, 255), 
                                     -1)
                        
                        # Draw text in black for contrast
                        cv2.putText(result_image, text, (global_x1, global_y1-10), 
                                    cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 2)
    
    # Calculate total processing time
    end_time = time.time
    # Calculate total processing time
    end_time = time.time()
    total_time = end_time - start_time
    print(f"Detected {tree_count} palm trees in {total_time:.2f} seconds.")
    
    # Save result
    cv2.imwrite('counted_palms.jpg', result_image)
    # return result_image, tree_count

def calculate_iou(box1, box2):
    # Calculate intersection over union to avoid duplicate detections
    x1 = max(box1[0], box2[0])
    y1 = max(box1[1], box2[1])
    x2 = min(box1[2], box2[2])
    y2 = min(box1[3], box2[3])
    
    if x2 < x1 or y2 < y1:
        return 0.0
        
    intersection = (x2 - x1) * (y2 - y1)
    area1 = (box1[2] - box1[0]) * (box1[3] - box1[1])
    area2 = (box2[2] - box2[0]) * (box2[3] - box2[1])
    
    return intersection / float(area1 + area2 - intersection)

# %%
# Load your YOLO model
trained_model = YOLO("/workspace/palmtree/runs/detect/train6/weights/best.pt")
trained_model.overrides['imgsz'] = 640 #overriding model input image for precision in cost of inference time
trained_model.overrides['verbose'] = False
image_source = "/workspace/palmtree/Palm-Tree-Detection-1/count1.jpeg"

# Run detection with tiling
detect_trees_with_tiling(image_source, trained_model, tile_size=640, overlap=0.2)
# Out:
# Loading image: /workspace/palmtree/Palm-Tree-Detection-1/count1.jpeg
# Image dimensions: 5954x6978
# Processing with tile size: 640px, overlap: 20.0%, step: 512px
# Detected 413 palm trees in 1.42 seconds.

# %%
# Load your YOLO model
trained_model = YOLO("/workspace/palmtree/runs/detect/train6/weights/best.pt")
trained_model.overrides['imgsz'] = 1280 #overriding model input image for precision in cost of inference time
trained_model.overrides['verbose'] = False
image_source = "/workspace/palmtree/Palm-Tree-Detection-1/count1.jpeg"

# Run detection with tiling
detect_trees_with_tiling(image_source, trained_model, tile_size=640, overlap=0.2, conf_threshold=0.3, iou_threshold=0.7)
# Out:
# Loading image: /workspace/palmtree/Palm-Tree-Detection-1/count1.jpeg
# Image dimensions: 5954x6978
# Processing with tile size: 640px, overlap: 20.0%, step: 512px
# Detected 1063 palm trees in 2.35 seconds.

# %%
# Training Model Hyperparameter tuning adjusted for uplifting the Recall (Coverage)
imgsz: 1280 # Trade-off the inference time for detection quality (AP), to compensate low quality aerial imagery that having small scale of trees
box: 0.5 # Trade-off Bounding Box Precision for more loose overlapping bounding box generation due to dense nature of the plantation layout
iou: 0.8 # Allows more overlapping bounding box to be persist, showing more faded or incomplete tree
cls: 0.4 # Adjust the priority of classifying less important , the non-complex pattern nature of the oil palm tree and single class case
dfl: 0.5 # Adjust the quality of coordinate of bounding box 
mixup: 0.3 # 
copy_paste: 0.3 # Mitigation for small datasets (by create new object arrangement that differ from neat layout of plantation)

# Modified Inference parameter for higher recall (Coverage)
conf: 0.2  # Trade-off the precision for more trees detection by allowing more overlapped detected tree to be persist
iou: 0.8   # Adjusted overlapping tolerant to high due to narrow and dense oil palm plantation layout

# %%
# TRAINING WITH ADJUSTED HYPERPARAMETER
model = YOLO("yolo11n.pt")  # or your preferred model size
config_file = "/workspace/palmtree/yolo-training-config.yaml"
# Train with config file in a single line
tuned_model_results = model.train(cfg=config_file)
# Out:
# Ultralytics 8.3.91 🚀 Python-3.11.11 torch-2.6.0+cu126 CUDA:0 (NVIDIA GeForce RTX 4080 SUPER, 16077MiB)
# ...

# %%
# INFERENCE IN ADJUSTED MODEL 1280
# Load your YOLO model
trained_model = YOLO("/workspace/palmtree/runs/detect/train66/weights/best.pt")
trained_model.overrides['imgsz'] = 1280 #overriding model input image for precision in cost of inference time
trained_model.overrides['verbose'] = False
image_source = "/workspace/palmtree/Palm-Tree-Detection-1/count1.jpeg"

# Run detection with tiling
detect_trees_with_tiling(image_source, trained_model, tile_size=640, overlap=0.2, conf_threshold=0.3, iou_threshold=0.7)
# Out:
# Loading image: /workspace/palmtree/Palm-Tree-Detection-1/count1.jpeg
# Image dimensions: 5954x6978
# Processing with tile size: 640px, overlap: 20.0%, step: 512px
# Detected 832 palm trees in 2.35 seconds.

# %%
# INFERENCE IN ADJUSTED MODEL 640
# Load your YOLO model
trained_model = YOLO("/workspace/palmtree/runs/detect/train66/weights/best.pt")
trained_model.overrides['imgsz'] = 640 #overriding model input image for precision in cost of inference time
trained_model.overrides['verbose'] = False
image_source = "/workspace/palmtree/Palm-Tree-Detection-1/count1.jpeg"

# Run detection with tiling
detect_trees_with_tiling(image_source, trained_model, tile_size=640, overlap=0.2, conf_threshold=0.3, iou_threshold=0.7)
# Out:
# Loading image: /workspace/palmtree/Palm-Tree-Detection-1/count1.jpeg
# Image dimensions: 5954x6978
# Processing with tile size: 640px, overlap: 20.0%, step: 512px
# Detected 1264 palm trees in 1.83 seconds.

# %%
#NEW

# INFERENCE IN ADJUSTED MODEL 640
# Load your YOLO model

# /home/halfinamoon/projects/Aerial Palm Tree Object Detection/notebooks/experiments/count-target.jpeg
# /home/halfinamoon/projects/Aerial Palm Tree Object Detection/notebooks/experiments/runs/detect/train66/weights/best.pt

trained_model = YOLO("/home/halfinamoon/projects/Aerial Palm Tree Object Detection/notebooks/experiments/runs/detect/train66/weights/best.pt")
trained_model.overrides['imgsz'] = 640 #overriding model input image for precision in cost of inference time
trained_model.overrides['verbose'] = False
image_source = "//home/halfinamoon/projects/Aerial Palm Tree Object Detection/notebooks/experiments/count-target.jpeg"

# Run detection with tiling
detect_trees_with_tiling(image_source, trained_model, tile_size=640, overlap=0.2, conf_threshold=0.4, iou_threshold=0.7)
# Out:
# Loading image: //home/halfinamoon/projects/Aerial Palm Tree Object Detection/notebooks/experiments/count-target.jpeg
# Image dimensions: 5954x6978
# Processing with tile size: 640px, overlap: 20.0%, step: 512px
# Detected 725 palm trees in 5.19 seconds.

# %%
#NEW

# INFERENCE IN ADJUSTED MODEL 640
# Load your YOLO model

# /home/halfinamoon/projects/Aerial Palm Tree Object Detection/notebooks/experiments/count-target.jpeg
# /home/halfinamoon/projects/Aerial Palm Tree Object Detection/notebooks/experiments/runs/detect/train66/weights/best.pt

trained_model = YOLO("/home/halfinamoon/projects/Aerial Palm Tree Object Detection/notebooks/experiments/runs/detect/train66/weights/best.pt")
trained_model.overrides['imgsz'] = 640 #overriding model input image for precision in cost of inference time
trained_model.overrides['verbose'] = False
image_source = "//home/halfinamoon/projects/Aerial Palm Tree Object Detection/notebooks/experiments/count-target.jpeg"

# Run detection with tiling
detect_trees_with_tiling(image_source, trained_model, tile_size=640, overlap=0.2, conf_threshold=0.4, iou_threshold=0.7)
# Out:
# Loading image: //home/halfinamoon/projects/Aerial Palm Tree Object Detection/notebooks/experiments/count-target.jpeg
# Image dimensions: 5954x6978
# Processing with tile size: 640px, overlap: 20.0%, step: 512px
# Detected 725 palm trees in 10.63 seconds.

# %%
#NEW

# INFERENCE IN ADJUSTED MODEL 640
# Load your YOLO model

# /home/halfinamoon/projects/Aerial Palm Tree Object Detection/notebooks/experiments/count-target.jpeg
# /home/halfinamoon/projects/Aerial Palm Tree Object Detection/notebooks/experiments/runs/detect/train66/weights/best.pt

trained_model = YOLO("/home/halfinamoon/projects/Aerial Palm Tree Object Detection/notebooks/experiments/runs/detect/train66/weights/best.pt")
trained_model.overrides['imgsz'] = 640 #overriding model input image for precision in cost of inference time
trained_model.overrides['verbose'] = False
image_source = "//home/halfinamoon/projects/Aerial Palm Tree Object Detection/notebooks/experiments/count-target.jpeg"

# Run detection with tiling
detect_trees_with_tiling(image_source, trained_model, tile_size=640, overlap=0.2, conf_threshold=0.2, iou_threshold=0.8)
# Out:
# Loading image: //home/halfinamoon/projects/Aerial Palm Tree Object Detection/notebooks/experiments/count-target.jpeg
# Image dimensions: 5954x6978
# Processing with tile size: 640px, overlap: 20.0%, step: 512px
# Detected 1055 palm trees in 5.52 seconds.

# %%
from ultralytics import YOLO
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

def validate_model_with_thresholds(model_path, data_yaml, thresholds=None):
    """
    Validate YOLOv11 model with different confidence thresholds and compare results.
    
    Args:
        model_path: Path to the trained model weights
        data_yaml: Path to the data YAML file
        thresholds: List of confidence thresholds to test (default: 0.1 to 0.9 in 0.1 steps)
    """
    # Load the model
    model = YOLO(model_path)
    
    # Default thresholds if none provided
    if thresholds is None:
        thresholds = np.arange(0.1, 0.8, 0.1)
    
    # Store results
    results = []
    
    # Test each threshold
    for conf in thresholds:
        print(f"\nValidating with confidence threshold = {conf}")
        
        # Run validation with specific confidence threshold
        metrics = model.val(data=data_yaml, conf=conf, verbose=True)
        
        # Extract key metrics - ensuring they're scalar values
        precision = float(metrics.box.p)  # Convert to float
        recall = float(metrics.box.r)     # Convert to float
        
        # Calculate F1 score with scalar values
        f1_score = 2 * (precision * recall) / (precision + recall + 1e-16)
        
        result = {
            'conf_threshold': float(conf),  # Convert to float
            'precision': precision,
            'recall': recall,
            'mAP50': float(metrics.box.map50),
            'mAP50-95': float(metrics.box.map),
            'f1': f1_score
        }
        
        results.append(result)
        print(f"Precision: {result['precision']:.4f}, Recall: {result['recall']:.4f}, F1: {result['f1']:.4f}")
    
    # Convert to DataFrame
    results_df = pd.DataFrame(results)
    
    # Find threshold with maximum F1 score
    best_f1_idx = results_df['f1'].idxmax()
    best_threshold = results_df.loc[best_f1_idx, 'conf_threshold']
    
    print(f"\nBest confidence threshold based on F1 score: {best_threshold:.2f}")
    print(f"At this threshold - Precision: {results_df.loc[best_f1_idx, 'precision']:.4f}, " 
          f"Recall: {results_df.loc[best_f1_idx, 'recall']:.4f}, "
          f"F1: {results_df.loc[best_f1_idx, 'f1']:.4f}")
    
    # Plot results
    plot_results(results_df)
    
    return results_df

def plot_results(results_df):
    """Plot precision, recall, and F1 against confidence thresholds."""
    plt.figure(figsize=(12, 8))
    
    # Plot metrics vs threshold
    plt.subplot(1, 2, 1)
    plt.plot(results_df['conf_threshold'], results_df['precision'], 'b-', label='Precision')
    plt.plot(results_df['conf_threshold'], results_df['recall'], 'r-', label='Recall')
    plt.plot(results_df['conf_threshold'], results_df['f1'], 'g-', label='F1 Score')
    plt.xlabel('Confidence Threshold')
    plt.ylabel('Score')
    plt.title('Metrics vs Confidence Threshold')
    plt.grid(True)
    plt.legend()
    
    # Plot Precision-Recall curve
    plt.subplot(1, 2, 2)
    plt.plot(results_df['recall'], results_df['precision'], 'bo-')
    
    # Add threshold annotations
    for i, row in results_df.iterrows():
        plt.annotate(f"{row['conf_threshold']:.2f}", (row['recall'], row['precision']), textcoords="offset points", xytext=(0,10), ha='center')
    
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.title('Precision-Recall Curve')
    plt.grid(True)
    plt.show()

# %%
# Example usage
model_path = '/home/halfinamoon/projects/Aerial Palm Tree Object Detection/notebooks/experiments/runs/detect/train66/weights/best.pt'
data_yaml = '/home/halfinamoon/projects/Aerial Palm Tree Object Detection/data/count/raw/data.yaml'
validate_model_with_thresholds(model_path, data_yaml)
# Out:
# Validating with confidence threshold = 0.1
# Ultralytics 8.3.40 🚀 Python-3.11.11 torch-2.6.0+cu126 CUDA:0 (NVIDIA GeForce GTX 1650 Ti, 4096MiB)
# YOLO11n summary (fused): 238 layers, 2,582,347 parameters, 0 gradients, 6.3 GFLOPs
# val: Scanning /home/halfinamoon/projects/Aerial Palm Tree Object Detection/data/count/raw/valid/labels.cache... 20 images, 2 backgrounds, 0 corrupt: 100%|██████████| 20/20 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:15<00:00,  7.85s/it]
#                    all         20         53      0.884      0.887      0.942      0.694
# Speed: 105.1ms preprocess, 144.5ms inference, 0.0ms loss, 3.7ms postprocess per image
# Results saved to runs/detect/val8
# Precision: 0.8844, Recall: 0.8868, F1: 0.8856
#
# Validating with confidence threshold = 0.2
# Ultralytics 8.3.40 🚀 Python-3.11.11 torch-2.6.0+cu126 CUDA:0 (NVIDIA GeForce GTX 1650 Ti, 4096MiB)
# ...
